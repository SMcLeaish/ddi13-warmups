# %%
import pandas as pd
data = {
    "product": ["pen","mug","book","lamp","cable","notebook","bottle","mouse"],
    "price":   ["2.5", "12.0", "22.0", "18.5", "9.5", "11.0", "25.0", "15.0"],
    "cat":     ["office","kitchen","books","home","electronics","office","kitchen","electronics"]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     product price          cat
# 0       pen   2.5       office
# 1       mug  12.0      kitchen
# 2      book  22.0        books
# 3      lamp  18.5         home
# 4     cable   9.5  electronics
# 5  notebook  11.0       office
# 6    bottle  25.0      kitchen
# 7     mouse  15.0  electronics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   product  8 non-null      object
#  1   price    8 non-null      object
#  2   cat      8 non-null      object
# dtypes: object(3)
# memory usage: 324.0+ bytes

# %%
df['price'] = df['price'].astype('float')

# %%
electronics_mean  = df.groupby('cat')['price'].mean().loc['electronics']
office_mean =  df.groupby('cat')['price'].mean().loc['office']

# %%
electronics_items = df[df['cat'] == 'electronics']

# %%
office_items = df[df['cat'] == 'office']

# %%
print(f''' 
Electronics mean: {electronics_mean}
Electronics items: 
{electronics_items}
Office mean: {office_mean}
Office items: 
{office_items}
''')
# Out:
#
# Electronics mean: 12.25
# Electronics items:
#   product  price          cat
# 4   cable    9.5  electronics
# 7   mouse   15.0  electronics
# Office mean: 6.75
# Office items:
#     product  price     cat
# 0       pen    2.5  office
# 5  notebook   11.0  office

# %%
import seaborn as sns
sns.histplot(data=df, x='price', color='darkgreen',bins=10 )
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# Out:
# array([[<Axes: title={'center': 'price'}>]], dtype=object)

# %%
df.hist('price', color='darkgreen', grid=False)
